# %% [markdown]
# <a href="https://colab.research.google.com/github/bhumika2406/PRODIGY_DS_01/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Loading dataset
data = pd.read_csv("Housing.csv")
# Histogram for price
plt.hist(data['price'], bins=20, edgecolor='black')
plt.title("Distribution of House Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()
